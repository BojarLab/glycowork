# %%
#hide
#all_slow

# %%
#hide
#default_exp glycan_data
from nbdev.showdoc import show_doc
from IPython.display import HTML
import copy
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # glycan_data
#
# >Loading and handling glycan datasets

# %%
#export
from glycowork.glycan_data.loader import *
from glycowork.glycan_data.data_entry import *

# %% [markdown]
# `glycan_data` contains several helper functions for glycan data loading and data entry. Helper functions for data loading and data objects are in `loader` and include:
# - `unwrap` flattens nested lists
# - `find_nth` returns the n-th occurrence of a motif
# - `df_species` loaded file for all glycans with species information, one row per glycan-species combination
# - `df_glycan` loaded file containing all unique glycans with lots of meta-information
# - `df_glysum` loaded glycan substitution matrix for glycan alignment
# - `glycan_emb` glycan representations for all glycans in df_species from a trained species-level SweetNet model
# - `influenza_binding` Z-score data for influenza virus binding to glycans; every row one virus, glycans are columns
# - `lib` library of unique monosaccharides + linkages in stored datasets; generated with `get_lib`

# %% [markdown]
# # loader

# %%
show_doc(unwrap)
# Out:
# <h4 id="unwrap" class="doc_header"><code>unwrap</code><a href="https://github.com/BojarLab/glycowork/tree/master/glycowork/glycan_data/loader.py#L35" class="source_link" style="float:right">[source]</a></h4>
#
# > <code>unwrap</code>(**`nested_list`**)
#
# converts a nested list into a flat list

# %%
unwrap([[1,2], [3,4]])
# Out:
# [1, 2, 3, 4]

# %%
show_doc(find_nth)
# Out:
# <h4 id="find_nth" class="doc_header"><code>find_nth</code><a href="https://github.com/BojarLab/glycowork/tree/master/glycowork/glycan_data/loader.py#L40" class="source_link" style="float:right">[source]</a></h4>
#
# > <code>find_nth</code>(**`haystack`**, **`needle`**, **`n`**)
#
# finds n-th instance of motif
#
# | Arguments:
# | :-
# | haystack (string): string to search for motif
# | needle (string): motif
# | n (int): n-th occurrence in string
#
# | Returns:
# | :-
# | Returns starting index of n-th occurrence in string

# %%
find_nth('This is as good as it gets', 'as', 2)
# Out:
# 16

# %% [markdown]
# `df_species`

# %%
#hide_input
df_species2 = copy.deepcopy(df_species)
df_species2.index = df_species2.target.values.tolist()
df_species2.drop(['target'], axis = 1, inplace = True)
HTML(df_species2.head().style.set_properties(**{'font-size': '11pt', 'font-family': 'Helvetica','border-collapse': 'collapse','border': '1px solid black'}).render())
# Out:
# <style  type="text/css" >
# #T_c0ac3_row0_col0,#T_c0ac3_row0_col1,#T_c0ac3_row0_col2,#T_c0ac3_row0_col3,#T_c0ac3_row0_col4,#T_c0ac3_row0_col5,#T_c0ac3_row0_col6,#T_c0ac3_row0_col7,#T_c0ac3_row0_col8,#T_c0ac3_row1_col0,#T_c0ac3_row1_col1,#T_c0ac3_row1_col2,#T_c0ac3_row1_col3,#T_c0ac3_row1_col4,#T_c0ac3_row1_col5,#T_c0ac3_row1_col6,#T_c0ac3_row1_col7,#T_c0ac3_row1_col8,#T_c0ac3_row2_col0,#T_c0ac3_row2_col1,#T_c0ac3_row2_col2,#T_c0ac3_row2_col3,#T_c0ac3_row2_col4,#T_c0ac3_row2_col5,#T_c0ac3_row2_col6,#T_c0ac3_row2_col7,#T_c0ac3_row2_col8,#T_c0ac3_row3_col0,#T_c0ac3_row3_col1,#T_c0ac3_row3_col2,#T_c0ac3_row3_col3,#T_c0ac3_row3_col4,#T_c0ac3_row3_col5,#T_c0ac3_row3_col6,#T_c0ac3_row3_col7,#T_c0ac3_row3_col8,#T_c0ac3_row4_col0,#T_c0ac3_row4_col1,#T_c0ac3_row4_col2,#T_c0ac3_row4_col3,#T_c0ac3_row4_col4,#T_c0ac3_row4_col5,#T_c0ac3_row4_col6,#T_c0ac3_row4_col7,#T_c0ac3_row4_col8{
#             font-size:  11pt;
#             font-family:  Helvetica;
#             border-collapse:  collapse;
#             border:  1px solid black;
#         }</style><table id="T_c0ac3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Species</th>        <th class="col_heading level0 col1" >Genus</th>        <th class="col_heading level0 col2" >Family</th>        <th class="col_heading level0 col3" >Order</th>        <th class="col_heading level0 col4" >Class</th>        <th class="col_heading level0 col5" >Phylum</th>        <th class="col_heading level0 col6" >Kingdom</th>        <th class="col_heading level0 col7" >Domain</th>        <th class="col_heading level0 col8" >ref</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c0ac3_level0_row0" class="row_heading level0 row0" >GlcA(b1-3)GalA(a1-2)Rha(a1-4)[GlcA(b1-3)]GalA(a1-2)Rha(a1-4)[GlcA(b1-3)]GalA(a1-2)Rha-ol</th>
#                         <td id="T_c0ac3_row0_col0" class="data row0 col0" >Abelmoschus_esculentus</td>
#                         <td id="T_c0ac3_row0_col1" class="data row0 col1" >Abelmoschus</td>
#                         <td id="T_c0ac3_row0_col2" class="data row0 col2" >Malvaceae</td>
#                         <td id="T_c0ac3_row0_col3" class="data row0 col3" >Malvales</td>
#                         <td id="T_c0ac3_row0_col4" class="data row0 col4" >Dicotyledons</td>
#                         <td id="T_c0ac3_row0_col5" class="data row0 col5" >Angiosperms</td>
#                         <td id="T_c0ac3_row0_col6" class="data row0 col6" >Plantae</td>
#                         <td id="T_c0ac3_row0_col7" class="data row0 col7" >Eukarya</td>
#                         <td id="T_c0ac3_row0_col8" class="data row0 col8" >G26314VL</td>
#             </tr>
#             <tr>
#                         <th id="T_c0ac3_level0_row1" class="row_heading level0 row1" >GalA(a1-2)Rha(a1-4)GalA</th>
#                         <td id="T_c0ac3_row1_col0" class="data row1 col0" >Abelmoschus_esculentus</td>
#                         <td id="T_c0ac3_row1_col1" class="data row1 col1" >Abelmoschus</td>
#                         <td id="T_c0ac3_row1_col2" class="data row1 col2" >Malvaceae</td>
#                         <td id="T_c0ac3_row1_col3" class="data row1 col3" >Malvales</td>
#                         <td id="T_c0ac3_row1_col4" class="data row1 col4" >Dicotyledons</td>
#                         <td id="T_c0ac3_row1_col5" class="data row1 col5" >Angiosperms</td>
#                         <td id="T_c0ac3_row1_col6" class="data row1 col6" >Plantae</td>
#                         <td id="T_c0ac3_row1_col7" class="data row1 col7" >Eukarya</td>
#                         <td id="T_c0ac3_row1_col8" class="data row1 col8" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_c0ac3_level0_row2" class="row_heading level0 row2" >[GlcA(b1-3)]GalA(a1-2)Rha(a1-4)GalA</th>
#                         <td id="T_c0ac3_row2_col0" class="data row2 col0" >Abelmoschus_esculentus</td>
#                         <td id="T_c0ac3_row2_col1" class="data row2 col1" >Abelmoschus</td>
#                         <td id="T_c0ac3_row2_col2" class="data row2 col2" >Malvaceae</td>
#                         <td id="T_c0ac3_row2_col3" class="data row2 col3" >Malvales</td>
#                         <td id="T_c0ac3_row2_col4" class="data row2 col4" >Dicotyledons</td>
#                         <td id="T_c0ac3_row2_col5" class="data row2 col5" >Angiosperms</td>
#                         <td id="T_c0ac3_row2_col6" class="data row2 col6" >Plantae</td>
#                         <td id="T_c0ac3_row2_col7" class="data row2 col7" >Eukarya</td>
#                         <td id="T_c0ac3_row2_col8" class="data row2 col8" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_c0ac3_level0_row3" class="row_heading level0 row3" >[Gal(b1-4)Gal(b1-4)]Rha(a1-2)Rha</th>
#                         <td id="T_c0ac3_row3_col0" class="data row3 col0" >Abelmoschus_esculentus</td>
#                         <td id="T_c0ac3_row3_col1" class="data row3 col1" >Abelmoschus</td>
#                         <td id="T_c0ac3_row3_col2" class="data row3 col2" >Malvaceae</td>
#                         <td id="T_c0ac3_row3_col3" class="data row3 col3" >Malvales</td>
#                         <td id="T_c0ac3_row3_col4" class="data row3 col4" >Dicotyledons</td>
#                         <td id="T_c0ac3_row3_col5" class="data row3 col5" >Angiosperms</td>
#                         <td id="T_c0ac3_row3_col6" class="data row3 col6" >Plantae</td>
#                         <td id="T_c0ac3_row3_col7" class="data row3 col7" >Eukarya</td>
#                         <td id="T_c0ac3_row3_col8" class="data row3 col8" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_c0ac3_level0_row4" class="row_heading level0 row4" >GlcA(b1-3)GalA(a1-2)Rha(a1-4)[GlcA(b1-3)]GalA(a1-2)Rha(a1-4)[GlcA(b1-3)]GalA(a1-2)Rha(a1-4)[GlcA(b1-3)]GalA(a1-2)Rha</th>
#                         <td id="T_c0ac3_row4_col0" class="data row4 col0" >Abelmoschus_esculentus</td>
#                         <td id="T_c0ac3_row4_col1" class="data row4 col1" >Abelmoschus</td>
#                         <td id="T_c0ac3_row4_col2" class="data row4 col2" >Malvaceae</td>
#                         <td id="T_c0ac3_row4_col3" class="data row4 col3" >Malvales</td>
#                         <td id="T_c0ac3_row4_col4" class="data row4 col4" >Dicotyledons</td>
#                         <td id="T_c0ac3_row4_col5" class="data row4 col5" >Angiosperms</td>
#                         <td id="T_c0ac3_row4_col6" class="data row4 col6" >Plantae</td>
#                         <td id="T_c0ac3_row4_col7" class="data row4 col7" >Eukarya</td>
#                         <td id="T_c0ac3_row4_col8" class="data row4 col8" >nan</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# `df_glycan`

# %%
#hide_input
df_glycan.index = df_glycan.glycan.values.tolist()
df_glycan.drop(['glycan'], axis = 1, inplace = True)
HTML(df_glycan.head().style.set_properties(**{'font-size': '11pt', 'font-family': 'Helvetica','border-collapse': 'collapse','border': '1px solid black'}).render())
# Out:
# <style  type="text/css" >
# #T_c6897_row0_col0,#T_c6897_row0_col1,#T_c6897_row0_col2,#T_c6897_row0_col3,#T_c6897_row0_col4,#T_c6897_row0_col5,#T_c6897_row0_col6,#T_c6897_row0_col7,#T_c6897_row0_col8,#T_c6897_row0_col9,#T_c6897_row0_col10,#T_c6897_row0_col11,#T_c6897_row0_col12,#T_c6897_row0_col13,#T_c6897_row1_col0,#T_c6897_row1_col1,#T_c6897_row1_col2,#T_c6897_row1_col3,#T_c6897_row1_col4,#T_c6897_row1_col5,#T_c6897_row1_col6,#T_c6897_row1_col7,#T_c6897_row1_col8,#T_c6897_row1_col9,#T_c6897_row1_col10,#T_c6897_row1_col11,#T_c6897_row1_col12,#T_c6897_row1_col13,#T_c6897_row2_col0,#T_c6897_row2_col1,#T_c6897_row2_col2,#T_c6897_row2_col3,#T_c6897_row2_col4,#T_c6897_row2_col5,#T_c6897_row2_col6,#T_c6897_row2_col7,#T_c6897_row2_col8,#T_c6897_row2_col9,#T_c6897_row2_col10,#T_c6897_row2_col11,#T_c6897_row2_col12,#T_c6897_row2_col13,#T_c6897_row3_col0,#T_c6897_row3_col1,#T_c6897_row3_col2,#T_c6897_row3_col3,#T_c6897_row3_col4,#T_c6897_row3_col5,#T_c6897_row3_col6,#T_c6897_row3_col7,#T_c6897_row3_col8,#T_c6897_row3_col9,#T_c6897_row3_col10,#T_c6897_row3_col11,#T_c6897_row3_col12,#T_c6897_row3_col13,#T_c6897_row4_col0,#T_c6897_row4_col1,#T_c6897_row4_col2,#T_c6897_row4_col3,#T_c6897_row4_col4,#T_c6897_row4_col5,#T_c6897_row4_col6,#T_c6897_row4_col7,#T_c6897_row4_col8,#T_c6897_row4_col9,#T_c6897_row4_col10,#T_c6897_row4_col11,#T_c6897_row4_col12,#T_c6897_row4_col13{
#             font-size:  11pt;
#             font-family:  Helvetica;
#             border-collapse:  collapse;
#             border:  1px solid black;
#         }</style><table id="T_c6897_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >glycan_id</th>        <th class="col_heading level0 col1" >Species</th>        <th class="col_heading level0 col2" >Genus</th>        <th class="col_heading level0 col3" >Family</th>        <th class="col_heading level0 col4" >Order</th>        <th class="col_heading level0 col5" >Class</th>        <th class="col_heading level0 col6" >Phylum</th>        <th class="col_heading level0 col7" >Kingdom</th>        <th class="col_heading level0 col8" >Domain</th>        <th class="col_heading level0 col9" >ref</th>        <th class="col_heading level0 col10" >glytoucan_id</th>        <th class="col_heading level0 col11" >predicted_taxonomy</th>        <th class="col_heading level0 col12" >glycan_type</th>        <th class="col_heading level0 col13" >immunogenicity</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c6897_level0_row0" class="row_heading level0 row0" >1,5-Anhydro-ManNAc-ol(2-4)GlcNAc1N</th>
#                         <td id="T_c6897_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_c6897_row0_col1" class="data row0 col1" >[]</td>
#                         <td id="T_c6897_row0_col2" class="data row0 col2" >[]</td>
#                         <td id="T_c6897_row0_col3" class="data row0 col3" >[]</td>
#                         <td id="T_c6897_row0_col4" class="data row0 col4" >[]</td>
#                         <td id="T_c6897_row0_col5" class="data row0 col5" >[]</td>
#                         <td id="T_c6897_row0_col6" class="data row0 col6" >[]</td>
#                         <td id="T_c6897_row0_col7" class="data row0 col7" >[]</td>
#                         <td id="T_c6897_row0_col8" class="data row0 col8" >[]</td>
#                         <td id="T_c6897_row0_col9" class="data row0 col9" >[]</td>
#                         <td id="T_c6897_row0_col10" class="data row0 col10" >G14785ZN</td>
#                         <td id="T_c6897_row0_col11" class="data row0 col11" >Plantae</td>
#                         <td id="T_c6897_row0_col12" class="data row0 col12" >nan</td>
#                         <td id="T_c6897_row0_col13" class="data row0 col13" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_c6897_level0_row1" class="row_heading level0 row1" >2,3-Anhydro-Man(a1-4)Glc(a1-4)Glc</th>
#                         <td id="T_c6897_row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_c6897_row1_col1" class="data row1 col1" >[]</td>
#                         <td id="T_c6897_row1_col2" class="data row1 col2" >[]</td>
#                         <td id="T_c6897_row1_col3" class="data row1 col3" >[]</td>
#                         <td id="T_c6897_row1_col4" class="data row1 col4" >[]</td>
#                         <td id="T_c6897_row1_col5" class="data row1 col5" >[]</td>
#                         <td id="T_c6897_row1_col6" class="data row1 col6" >[]</td>
#                         <td id="T_c6897_row1_col7" class="data row1 col7" >[]</td>
#                         <td id="T_c6897_row1_col8" class="data row1 col8" >[]</td>
#                         <td id="T_c6897_row1_col9" class="data row1 col9" >[]</td>
#                         <td id="T_c6897_row1_col10" class="data row1 col10" >G86031XW</td>
#                         <td id="T_c6897_row1_col11" class="data row1 col11" >Bacteria</td>
#                         <td id="T_c6897_row1_col12" class="data row1 col12" >nan</td>
#                         <td id="T_c6897_row1_col13" class="data row1 col13" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_c6897_level0_row2" class="row_heading level0 row2" >2,3-Anhydro-Man(a1-4)Glc(a1-4)Glc-ol</th>
#                         <td id="T_c6897_row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_c6897_row2_col1" class="data row2 col1" >[]</td>
#                         <td id="T_c6897_row2_col2" class="data row2 col2" >[]</td>
#                         <td id="T_c6897_row2_col3" class="data row2 col3" >[]</td>
#                         <td id="T_c6897_row2_col4" class="data row2 col4" >[]</td>
#                         <td id="T_c6897_row2_col5" class="data row2 col5" >[]</td>
#                         <td id="T_c6897_row2_col6" class="data row2 col6" >[]</td>
#                         <td id="T_c6897_row2_col7" class="data row2 col7" >[]</td>
#                         <td id="T_c6897_row2_col8" class="data row2 col8" >[]</td>
#                         <td id="T_c6897_row2_col9" class="data row2 col9" >[]</td>
#                         <td id="T_c6897_row2_col10" class="data row2 col10" >G86383FW</td>
#                         <td id="T_c6897_row2_col11" class="data row2 col11" >Bacteria</td>
#                         <td id="T_c6897_row2_col12" class="data row2 col12" >nan</td>
#                         <td id="T_c6897_row2_col13" class="data row2 col13" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_c6897_level0_row3" class="row_heading level0 row3" >2,3-Anhydro-Man(bond)Glc(bond)Glc</th>
#                         <td id="T_c6897_row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_c6897_row3_col1" class="data row3 col1" >[]</td>
#                         <td id="T_c6897_row3_col2" class="data row3 col2" >[]</td>
#                         <td id="T_c6897_row3_col3" class="data row3 col3" >[]</td>
#                         <td id="T_c6897_row3_col4" class="data row3 col4" >[]</td>
#                         <td id="T_c6897_row3_col5" class="data row3 col5" >[]</td>
#                         <td id="T_c6897_row3_col6" class="data row3 col6" >[]</td>
#                         <td id="T_c6897_row3_col7" class="data row3 col7" >[]</td>
#                         <td id="T_c6897_row3_col8" class="data row3 col8" >[]</td>
#                         <td id="T_c6897_row3_col9" class="data row3 col9" >[]</td>
#                         <td id="T_c6897_row3_col10" class="data row3 col10" >G46167OL</td>
#                         <td id="T_c6897_row3_col11" class="data row3 col11" >Euryarchaeota</td>
#                         <td id="T_c6897_row3_col12" class="data row3 col12" >nan</td>
#                         <td id="T_c6897_row3_col13" class="data row3 col13" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_c6897_level0_row4" class="row_heading level0 row4" >2,3-Anhydro-Man(bond)Glc(bond)Glc-ol</th>

# %% [markdown]
# `influenza_binding`

# %%
#hide_input
HTML(influenza_binding.head().style.set_properties(**{'font-size': '11pt', 'font-family': 'Helvetica','border-collapse': 'collapse','border': '1px solid black'}).render())
# Out:
# <style  type="text/css" >
# #T_ebd74_row0_col0,#T_ebd74_row0_col1,#T_ebd74_row0_col2,#T_ebd74_row0_col3,#T_ebd74_row0_col4,#T_ebd74_row0_col5,#T_ebd74_row0_col6,#T_ebd74_row0_col7,#T_ebd74_row0_col8,#T_ebd74_row0_col9,#T_ebd74_row0_col10,#T_ebd74_row0_col11,#T_ebd74_row0_col12,#T_ebd74_row0_col13,#T_ebd74_row0_col14,#T_ebd74_row0_col15,#T_ebd74_row0_col16,#T_ebd74_row0_col17,#T_ebd74_row0_col18,#T_ebd74_row0_col19,#T_ebd74_row0_col20,#T_ebd74_row0_col21,#T_ebd74_row0_col22,#T_ebd74_row0_col23,#T_ebd74_row0_col24,#T_ebd74_row0_col25,#T_ebd74_row0_col26,#T_ebd74_row0_col27,#T_ebd74_row0_col28,#T_ebd74_row0_col29,#T_ebd74_row0_col30,#T_ebd74_row0_col31,#T_ebd74_row0_col32,#T_ebd74_row0_col33,#T_ebd74_row0_col34,#T_ebd74_row0_col35,#T_ebd74_row0_col36,#T_ebd74_row0_col37,#T_ebd74_row0_col38,#T_ebd74_row0_col39,#T_ebd74_row0_col40,#T_ebd74_row0_col41,#T_ebd74_row0_col42,#T_ebd74_row0_col43,#T_ebd74_row0_col44,#T_ebd74_row0_col45,#T_ebd74_row0_col46,#T_ebd74_row0_col47,#T_ebd74_row0_col48,#T_ebd74_row0_col49,#T_ebd74_row0_col50,#T_ebd74_row0_col51,#T_ebd74_row0_col52,#T_ebd74_row0_col53,#T_ebd74_row0_col54,#T_ebd74_row0_col55,#T_ebd74_row0_col56,#T_ebd74_row0_col57,#T_ebd74_row0_col58,#T_ebd74_row0_col59,#T_ebd74_row0_col60,#T_ebd74_row0_col61,#T_ebd74_row0_col62,#T_ebd74_row0_col63,#T_ebd74_row0_col64,#T_ebd74_row0_col65,#T_ebd74_row0_col66,#T_ebd74_row0_col67,#T_ebd74_row0_col68,#T_ebd74_row0_col69,#T_ebd74_row0_col70,#T_ebd74_row0_col71,#T_ebd74_row0_col72,#T_ebd74_row0_col73,#T_ebd74_row0_col74,#T_ebd74_row0_col75,#T_ebd74_row0_col76,#T_ebd74_row0_col77,#T_ebd74_row0_col78,#T_ebd74_row0_col79,#T_ebd74_row0_col80,#T_ebd74_row0_col81,#T_ebd74_row0_col82,#T_ebd74_row0_col83,#T_ebd74_row0_col84,#T_ebd74_row0_col85,#T_ebd74_row0_col86,#T_ebd74_row0_col87,#T_ebd74_row0_col88,#T_ebd74_row0_col89,#T_ebd74_row0_col90,#T_ebd74_row0_col91,#T_ebd74_row0_col92,#T_ebd74_row0_col93,#T_ebd74_row0_col94,#T_ebd74_row0_col95,#T_ebd74_row0_col96,#T_ebd74_row0_col97,#T_ebd74_row0_col98,#T_ebd74_row0_col99,#T_ebd74_row0_col100,#T_ebd74_row0_col101,#T_ebd74_row0_col102,#T_ebd74_row0_col103,#T_ebd74_row0_col104,#T_ebd74_row0_col105,#T_ebd74_row0_col106,#T_ebd74_row0_col107,#T_ebd74_row0_col108,#T_ebd74_row0_col109,#T_ebd74_row0_col110,#T_ebd74_row0_col111,#T_ebd74_row0_col112,#T_ebd74_row0_col113,#T_ebd74_row0_col114,#T_ebd74_row0_col115,#T_ebd74_row0_col116,#T_ebd74_row0_col117,#T_ebd74_row0_col118,#T_ebd74_row0_col119,#T_ebd74_row0_col120,#T_ebd74_row0_col121,#T_ebd74_row0_col122,#T_ebd74_row0_col123,#T_ebd74_row0_col124,#T_ebd74_row0_col125,#T_ebd74_row0_col126,#T_ebd74_row0_col127,#T_ebd74_row0_col128,#T_ebd74_row0_col129,#T_ebd74_row0_col130,#T_ebd74_row0_col131,#T_ebd74_row0_col132,#T_ebd74_row0_col133,#T_ebd74_row0_col134,#T_ebd74_row0_col135,#T_ebd74_row0_col136,#T_ebd74_row0_col137,#T_ebd74_row0_col138,#T_ebd74_row0_col139,#T_ebd74_row0_col140,#T_ebd74_row0_col141,#T_ebd74_row0_col142,#T_ebd74_row0_col143,#T_ebd74_row0_col144,#T_ebd74_row0_col145,#T_ebd74_row0_col146,#T_ebd74_row0_col147,#T_ebd74_row0_col148,#T_ebd74_row0_col149,#T_ebd74_row0_col150,#T_ebd74_row0_col151,#T_ebd74_row0_col152,#T_ebd74_row0_col153,#T_ebd74_row0_col154,#T_ebd74_row0_col155,#T_ebd74_row0_col156,#T_ebd74_row0_col157,#T_ebd74_row0_col158,#T_ebd74_row0_col159,#T_ebd74_row0_col160,#T_ebd74_row0_col161,#T_ebd74_row0_col162,#T_ebd74_row0_col163,#T_ebd74_row0_col164,#T_ebd74_row0_col165,#T_ebd74_row0_col166,#T_ebd74_row0_col167,#T_ebd74_row0_col168,#T_ebd74_row0_col169,#T_ebd74_row0_col170,#T_ebd74_row0_col171,#T_ebd74_row0_col172,#T_ebd74_row0_col173,#T_ebd74_row0_col174,#T_ebd74_row0_col175,#T_ebd74_row0_col176,#T_ebd74_row0_col177,#T_ebd74_row0_col178,#T_ebd74_row0_col179,#T_ebd74_row0_col180,#T_ebd74_row0_col181,#T_ebd74_row0_col182,#T_ebd74_row0_col183,#T_ebd74_row0_col184,#T_ebd74_row0_col185,#T_ebd74_row0_col186,#T_ebd74_row0_col187,#T_ebd74_row0_col188,#T_ebd74_row0_col189,#T_ebd74_row0_col190,#T_ebd74_row0_col191,#T_ebd74_row0_col192,#T_ebd74_row0_col193,#T_ebd74_row0_col194,#T_ebd74_row0_c ...

# %% [markdown]
# # data_entry

# %% [markdown]
# Helper functions for entering data are contained in `data_entry` and include:
#
# - `check_presence` tests whether the entered glycan is already in database

# %%
show_doc(check_presence)
# Out:
# <h4 id="check_presence" class="doc_header"><code>check_presence</code><a href="https://github.com/BojarLab/glycowork/tree/master/glycowork/glycan_data/data_entry.py#L5" class="source_link" style="float:right">[source]</a></h4>
#
# > <code>check_presence</code>(**`glycan`**, **`df`**, **`colname`**=*`'target'`*, **`libr`**=*`None`*, **`name`**=*`None`*, **`rank`**=*`'Species'`*, **`fast`**=*`False`*)
#
# checks whether glycan (of that species) is already present in dataset
#
# | Arguments:
# | :-
# | glycan (string): IUPAC-condensed glycan sequence
# | df (dataframe): glycan dataframe where glycans are under colname and ideally taxonomic labels are columns
# | libr (list): sorted list of unique glycoletters observed in the glycans of our dataset
# | name (string): name of the species (etc.) of interest
# | rank (string): column name for filtering; default: species
# | fast (bool): True uses precomputed glycan graphs, only use if df has column 'graph' with glycan graphs
#
# | Returns:
# | :-
# | Returns text output regarding whether the glycan is already in df

# %%
print("Check presence of Man(a1-3)[Man(a1-6)]Man(b1-4)GlcNAc(b1-4)GlcNAc")
check_presence('Man(a1-3)[Man(a1-6)]Man(b1-4)GlcNAc(b1-4)GlcNAc', df_species)

#print("Check presence of Fuc(b1-3)[Man(a1-6)]Man(b1-4)GlcNAc(b1-4)GlcNAc")
#check_presence('Fuc(b1-3)[Man(a1-6)]Man(b1-4)GlcNAc(b1-4)GlcNAc', df_species)

print("Check presence of Man(a1-3)[Man(a1-6)]Man(b1-4)GlcNAc(b1-4)GlcNAc in the species Danielus Bojarum")
check_presence('Man(a1-3)[Man(a1-6)]Man(b1-4)GlcNAc(b1-4)GlcNAc', df_species,
               name = 'Danielus Bojarum')
# Out:
# Check presence of Man(a1-3)[Man(a1-6)]Man(b1-4)GlcNAc(b1-4)GlcNAc
# Glycan already in dataset.
# Check presence of Man(a1-3)[Man(a1-6)]Man(b1-4)GlcNAc(b1-4)GlcNAc in the species Danielus Bojarum
# This is the best: Danielus_Bojarum is not in dataset
# It's your lucky day, this glycan is new!

# %%
#hide
from nbdev.export import notebook2script; notebook2script()
# Out:
# Converted 00_core.ipynb.
# Converted 01_alignment.ipynb.
# Converted 02_glycan_data.ipynb.
# Converted 03_ml.ipynb.
# Converted 04_motif.ipynb.
# Converted 05_examples.ipynb.
# Converted 06_network.ipynb.
# Converted index.ipynb.
